# %%
# mounting on google drive
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
os.chdir('/content/drive/MyDrive/precog/dc-trainer')
print(os.getcwd())

# %%
! git pull origin main

# %%
! pip install -r requirements.txt

# %%
#! git clone https://github.com/Jayden3316/dc-trainer

# %%
# load wandb api key
from google.colab import userdata
WANDB_API_KEY = userdata.get('WANDB_API_KEY')

import wandb
wandb.login(key=WANDB_API_KEY)

# %%
! python -m cli train --config-file experiments/training_configs/generation/convnext_medium_asymm_chr_transform_variable.yaml

# %%
# iterate through the csv files and split them depending on task:

import os
